# %%
from qiskit import QuantumCircuit
from qiskit.visualization import plot_bloch_multivector ,plot_state_qsphere
from qiskit.visualization import plot_state_qsphere, plot_histogram
some_state=[0,1]
plot_bloch_multivector(some_state)

# sv = Statevector.from_label('0')
# print(sv)

# %%
from qiskit.quantum_info import Statevector
sv = Statevector.from_label('0')
print(sv)
plot_bloch_multivector(sv)
# Out:
# Statevector([1.+0.j, 0.+0.j],
#             dims=(2,))

# %%
import numpy as np
from qiskit import QuantumCircuit
qc = QuantumCircuit(1)
qc.h(0)


qc.draw()
# Out:
#    ┌───┐
# q: ┤ H ├
#    └───┘

# %%
# !pip install pylatexenc

# %%
new_sv = sv.evolve(qc)
print(new_sv)
plot_bloch_multivector(new_sv)
# Out:
# Statevector([0.70710678+0.j, 0.70710678+0.j],
#             dims=(2,))

# %%
mycircuit = QuantumCircuit(2)
mycircuit.h(0)
mycircuit.cx(0,1)
mycircuit.draw()
# Out:
#      ┌───┐
# q_0: ┤ H ├──■──
#      └───┘┌─┴─┐
# q_1: ─────┤ X ├
#           └───┘

# %%
sv=Statevector.from_label('10')
plot_state_qsphere(sv.data)
plot_bloch_multivector(sv)

# %%
new_sv = sv.evolve(mycircuit)
print(new_sv)
plot_state_qsphere(new_sv.data)
# plot_bloch_multivector(new_sv)
# Out:
# Statevector([0.        +0.j, 0.70710678+0.j, 0.70710678+0.j,
#              0.        +0.j],
#             dims=(2, 2))

# %%
# running using a qasm_simulator (by default the input to the quantum circuits is zero )

# %%
mycircuit2 = QuantumCircuit(2,2)
mycircuit2.h(0)
mycircuit2.cx(0,1)
mycircuit2.measure(0,0)
mycircuit2.measure(1,1)
mycircuit2.draw()
# Out:
#      ┌───┐     ┌─┐
# q_0: ┤ H ├──■──┤M├───
#      └───┘┌─┴─┐└╥┘┌─┐
# q_1: ─────┤ X ├─╫─┤M├
#           └───┘ ║ └╥┘
# c: 2/═══════════╩══╩═
#                 0  1

# %%
from qiskit import Aer, execute, BasicAer
simulator=Aer.get_backend('qasm_simulator')
result=execute(mycircuit2, simulator, shots=1000).result()
counts=result.get_counts(mycircuit2)
plot_histogram(counts)

# %%
# running using a qasm_simulator (by default the input to the quantum circuits is zero )  so using a X gate for 10 to the circuit

# %%
mycircuit3 = QuantumCircuit(2,2)
mycircuit3.x(1)
mycircuit3.h(0)
mycircuit3.cx(0,1)
mycircuit3.measure(0,0)
mycircuit3.measure(1,1)
mycircuit3.draw()
# Out:
#      ┌───┐     ┌─┐
# q_0: ┤ H ├──■──┤M├───
#      ├───┤┌─┴─┐└╥┘┌─┐
# q_1: ┤ X ├┤ X ├─╫─┤M├
#      └───┘└───┘ ║ └╥┘
# c: 2/═══════════╩══╩═
#                 0  1

# %%
from qiskit import Aer, execute, BasicAer
simulator=Aer.get_backend('qasm_simulator')
result=execute(mycircuit3, simulator, shots=1000).result()
counts=result.get_counts(mycircuit3)
plot_histogram(counts)
